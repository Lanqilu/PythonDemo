# %%
# 时间相关方法
import datetime
d = datetime.date.today()
dt = datetime.datetime .now ()
print('当前日期 %s'%d)
print('当前时间 %s'%dt )
print('当前年份 %s'%dt.year)
print('当前月份 %s'%dt.month)
print('当前日期 %s'%dt.day)
print('当前小时 %s'%dt.hour)
print('当前分钟 %s'%dt.minute)
print('当前秒   %s'%dt.second)
# Out:
# 当前日期 2019-10-17
# 当前时间 2019-10-17 18:37:50.740423
# 当前年份 2019
# 当前月份 10
# 当前日期 17
# 当前小时 18
# 当前分钟 37
# 当前秒   50
