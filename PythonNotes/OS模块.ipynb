# %%
import os

# %% [markdown]
# `os.getcwd()`查看当前工作目录

# %%
path = os.getcwd()
print(path)
# Out:
# e:\Desktop\Python Project\100天Python

# %% [markdown]
# `os.chdir(path)`修改当前工作目录

# %%
path =  'e:\Desktop\Python Project\\100天Python'
os.chdir(path)
print(os.getcwd())
# Out:
# e:\Desktop\Python Project\100天Python

# %% [markdown]
# `os.system()`执行系统命令

# %%
os.system('mkdir "10天Python"')
# Out:
# 0

# %%
文本通配符

# %%
import glob
glob.glob('*.ipynb')
# Out:
# ['OS模块.ipynb', '列表.ipynb', '字符串.ipynb', '装饰器.ipynb', '面向对象.ipynb']

# %% [markdown]
# 命令行参数

# %%
import sys
print(sys.argv)
# Out:
# ['D:\\Python3.7.4\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\88524\\AppData\\Roaming\\jupyter\\runtime\\kernel-04fd3822-4305-42ef-9c86-7fb1b0cfe28a.json']

# %% [markdown]
# 性能度量

# %%
from timeit import Timer
a = Timer('t=a; a=b; b=t', 'a=1; b=2').timeit()
b = Timer('a,b = b,a', 'a=1; b=2').timeit()
print(str(a)+'\n'+str(b))
# Out:
# 0.03933299999994233
# 0.03145319999998719

# %% [markdown]
# 测试模块

# %%
def average(values):
    """Computes the arithmetic mean of a list of numbers.
    >>> print(average([20, 30, 70]))
    40.0
    """
    return sum(values) / len(values)

import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=1)
